# %% [markdown]
# <div style="background-color: #00e7c8ff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #fff;" align="center"><strong>USA Estate Data </strong></h1>
# </div>

# %% [markdown]
# <!-- image link of NY yellow taxi -->
#
# <div align="center"><img src="https://i0.wp.com/thetowerinfo.com/wp-content/uploads/2024/01/skyscrapers-america.jpg?fit=995%2C550&ssl=1" width="500" height="300"></div>

# %% [markdown]
# <div style="background-color: #e7092eff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #242222ff;" align="center"><strong> Exploratory Data Analysis </strong></h1>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="background-color: #00e7c8ff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #fff;" align="center"><strong>Loading And Checking the Dataset</strong></h1>
# </div>

# %%
data = pd.read_csv(r"C:\Users\katka\Desktop\github projrct\Self_Project\Python\realtor-data.zip.csv\realtor-data.zip.csv")

# %%
data
# Out:
#          brokered_by    status     price  bed  bath  acre_lot     street  \
# 0           103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1            52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2           103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3            31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4            34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
# ...              ...       ...       ...  ...   ...       ...        ...
# 2226377      23009.0      sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0      sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0      sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0      sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0      sold  580000.0  5.0   3.0      0.31   307704.0
#
#                city        state  zip_code  house_size prev_sold_date
# ...

# %% [markdown]
# <div style="background-color: #e7092eff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #242222ff;" align="center"><strong> Initial Inspection </strong></h1>
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(8), object(4)
# memory usage: 203.8+ MB

# %%
data.shape
# Out:
# (2226382, 12)

# %% [markdown]
# <div style="background-color: #00e7c8ff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #fff;" align="center"><strong>Statastical Analysis</strong></h1>
# </div>

# %%
data.describe()
# Out:
#         brokered_by         price           bed          bath      acre_lot  \
# count  2.221849e+06  2.224841e+06  1.745065e+06  1.714611e+06  1.900793e+06
# mean   5.293989e+04  5.241955e+05  3.275841e+00  2.496440e+00  1.522303e+01
# std    3.064275e+04  2.138893e+06  1.567274e+00  1.652573e+00  7.628238e+02
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.386100e+04  1.650000e+05  3.000000e+00  2.000000e+00  1.500000e-01
# 50%    5.288400e+04  3.250000e+05  3.000000e+00  2.000000e+00  2.600000e-01
# 75%    7.918300e+04  5.500000e+05  4.000000e+00  3.000000e+00  9.800000e-01
# max    1.101420e+05  2.147484e+09  4.730000e+02  8.300000e+02  1.000000e+05
#
#              street      zip_code    house_size
# count  2.215516e+06  2.226083e+06  1.657898e+06
# mean   1.012325e+06  5.218668e+04  2.714471e+03
# std    5.837635e+05  2.895408e+04  8.081635e+05
# min    0.000000e+00  0.000000e+00  4.000000e+00
# ...

# %% [markdown]
# <div style="background-color: #e7092eff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #242222ff;" align="center"><strong> Data Cleaning </strong></h1>
# </div>

# %%
# Dropping irrelevant columns for analysis
data.drop(columns=['brokered_by','street'], inplace=True, errors='ignore')

# %%
data.head()
# Out:
#      status     price  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  105000.0  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale   80000.0  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale   67000.0  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  145000.0  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale   65000.0  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date
# 0       920.0            NaN
# 1      1527.0            NaN
# 2       748.0            NaN
# 3      1800.0            NaN
# 4         NaN            NaN

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# status                 0
# price               1541
# bed               481317
# bath              511771
# acre_lot          325589
# city                1407
# state                  8
# zip_code             299
# house_size        568484
# prev_sold_date    734297
# dtype: int64

# %%
# Filling missing values with median for numerical columns
num_cols = ['price','bed','bath','acre_lot','house_size']
for col in num_cols:
    if col in data.columns:
        data[col] = data[col].fillna(data[col].median())

# %%
# Fill missing values with mode for categorical columns
cat_cols = ['status','city','state']
for col in cat_cols:
    if col in data.columns:
        data[col] = data[col].fillna(data[col].mode())

# %%
data.isnull().sum()
# Out:
# status                 0
# price                  0
# bed                    0
# bath                   0
# acre_lot               0
# city                1407
# state                  8
# zip_code             299
# house_size             0
# prev_sold_date    734297
# dtype: int64

# %%
# Dropping rows with missing values in critical columns
data.dropna(subset=['zip_code','prev_sold_date'], inplace=True)

# %%
data.isnull().sum()
# Out:
# status              0
# price               0
# bed                 0
# bath                0
# acre_lot            0
# city              338
# state               0
# zip_code            0
# house_size          0
# prev_sold_date      0
# dtype: int64

# %%
# Changing data types of certain columns
data['zip_code'] = data['zip_code'].astype('Int64', errors='ignore')
data['price'] = data['price'].astype('Int64', errors='ignore')
data['prev_sold_date'] = pd.to_datetime(data['prev_sold_date'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1492057 entries, 411 to 2226381
# Data columns (total 10 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   status          1492057 non-null  object
#  1   price           1492057 non-null  Int64
#  2   bed             1492057 non-null  float64
#  3   bath            1492057 non-null  float64
#  4   acre_lot        1492057 non-null  float64
#  5   city            1491719 non-null  object
#  6   state           1492057 non-null  object
#  7   zip_code        1492057 non-null  Int64
#  8   house_size      1492057 non-null  float64
#  9   prev_sold_date  1492056 non-null  datetime64[ns]
# dtypes: Int64(2), datetime64[ns](1), float64(4), object(3)
# memory usage: 128.1+ MB

# %%
# Checking for duplicates
data.duplicated().sum()
# Out:
# 6598

# %%
# Dropping duplicates
data.drop_duplicates(inplace=True)

# %%
# resetting index after dropping rows
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#      status   price  bed  bath  acre_lot          city           state  \
# 0  for_sale   76900  3.0   2.0      0.26     Canovanas     Puerto Rico
# 1  for_sale  110000  7.0   3.0      0.09        Dorado     Puerto Rico
# 2  for_sale  159000  3.0   2.0      0.26        Caguas     Puerto Rico
# 3  for_sale  380000  3.0   2.0     78.66       Yabucoa     Puerto Rico
# 4  for_sale  950000  5.0   4.0      0.99  Saint Thomas  Virgin Islands
#
#    zip_code  house_size prev_sold_date
# 0       729      1200.0     2020-02-28
# 1       949      1192.0     2019-06-28
# 2       725      1625.0     2021-09-15
# 3       767      1760.0     2021-03-15
# 4       802      5000.0     2013-10-11

# %% [markdown]
# <div style="background-color: #00e7c8ff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #fff;" align="center"><strong> Analyzing Outliers</strong></h1>
# </div>

# %%
# Find Outliers using IQR method
def analyze_outliers(series):
    q1 = series.quantile(0.25)  # First quartile
    q2 =series.quantile(0.50)  # Second quartile (median)
    q3 = series.quantile(0.75)  # Third quartile
    iqr = q3-q1 # Interquartile range
    lower_bound = q1 - 1.5 * iqr  # Lower bound for outliers
    upper_bound = q3 + 1.5 * iqr  # Upper bound for outliers
    outlier = series[(series < lower_bound) | (series > upper_bound)]  # Identify outliers
    summary={
        "25 th percentile": q1,
        "50 th percentile": q2,
        "_75 th percentile": q3,
        "IQR": iqr,
        "Lower bound": lower_bound,
        "Upper bound": upper_bound,
        "Outlier_Count": outlier.size,
        "Outliers List": np.sort(outlier.unique())
    }
    return summary

# %%
# Outlier from price column
analyze_outliers(data['price'])
# Out:
# {'25 th percentile': 209000.0,
#  '50 th percentile': 350000.0,
#  '_75 th percentile': 580000.0,
#  'IQR': 371000.0,
#  'Lower bound': -347500.0,
#  'Upper bound': 1136500.0,
#  'Outlier_Count': 117536,
#  'Outliers List': array([  1136900,   1137000,   1137500, ..., 295000000, 515000000,
#         875000000], dtype=int64)}

# %%
# analysing upper bound for price column
analyze_outliers(data['price'])['Upper bound']
# Out:
# 1136500.0

# %%
# Remove Outliers from price column
removed_outliers = data[data['price'] <= analyze_outliers(data['price'])['Upper bound']]

# %%
removed_outliers.describe() # Get descriptive statistics of the dataframe after removing outliers
# Out:
#                price           bed          bath      acre_lot      zip_code  \
# count      1367923.0  1.367923e+06  1.367923e+06  1.367923e+06     1367923.0
# mean   373056.807624  3.150807e+00  2.296623e+00  1.074602e+01  51986.873643
# min              0.0  1.000000e+00  1.000000e+00  0.000000e+00         602.0
# 25%         196000.0  3.000000e+00  2.000000e+00  1.500000e-01       29582.0
# 50%         326000.0  3.000000e+00  2.000000e+00  2.500000e-01       46410.0
# 75%         499995.0  4.000000e+00  3.000000e+00  4.000000e-01       77979.0
# max        1136000.0  4.440000e+02  8.300000e+02  1.000000e+05       99901.0
# std    238067.426958  1.173941e+00  1.264358e+00  7.476017e+02  29271.064047
#
#          house_size                 prev_sold_date
# count  1.367923e+06                        1367922
# mean   1.850611e+03  2017-10-06 04:41:14.414769664
# min    1.000000e+02            1901-01-01 00:00:00
# 25%    1.324000e+03            2016-12-02 00:00:00
# ...

# %% [markdown]
# <div style="background-color: #e7092eff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #242222ff;" align="center"><strong> Data Analysis and Visualization </strong></h1>
# </div>

# %%
# Top 10 states by number of listings
top_cities = data['city'].value_counts().head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=top_cities.index, y=top_cities.values,hue=top_cities.index, color='steelblue', palette="Set2")
plt.title("Top 10 Cities by Number of Listings")
plt.ylabel("Number of Listings")
plt.xlabel("City")
plt.xticks(rotation=45)
plt.show()

# %%
# Price distribution 
plt.figure(figsize=(10,6))
sns.histplot(removed_outliers['price'], bins=30, kde=True, color='#00A699')
plt.title('Price Distribution after Removing Outliers')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
top_states = data['state'].value_counts().head(10)
sns.barplot(x=top_states.index, y=top_states.values,hue=top_states.index, color='steelblue', palette="viridis")
plt.title("Top 10 States by Number of Listings")
plt.ylabel("Number of Listings")
plt.xlabel("State")
plt.xticks(rotation=45)
plt.show()

# %%
# Top 8 states by number of listings (share %)
top_states = data['state'].value_counts().head(8)

plt.figure(figsize=(8,8))
plt.pie(top_states.values, labels=top_states.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Top 8 States by Listings (Share %)")
plt.show()

# %%
# Median house price by state (top 10)
state_prices = data.groupby('state')['price'].median().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,6))
sns.lineplot(x=state_prices.index, y=state_prices.values, marker="o", color="steelblue", markersize=10)
plt.title("Median House Price by State (Top 10)")
plt.ylabel("Median Price")
plt.xlabel("State")
plt.xticks(rotation=45)
plt.show()

# %%
# Top 10 states by median price per sqft
data['price_per_sqft'] = data['price'] / data['house_size']
plt.figure(figsize=(12,6))
state_pps = data.groupby('state')['price_per_sqft'].median().sort_values(ascending=False).head(10)
sns.barplot(x=state_pps.values, y=state_pps.index,hue=state_pps.index, color='steelblue', palette="coolwarm",orient="h")
plt.title("Top 10 States by Median Price per Sqft")
plt.ylabel("State")
plt.xlabel("Median Price per Sqft")
plt.xticks(rotation=45)
plt.show()

# %%
def price_category(price):
    if price < 200000:
        return "Affordable"
    elif price < 700000:
        return "Mid-range"
    else:
        return "Luxury"

data['price_category'] = data['price'].apply(price_category)

plt.figure(figsize=(8,6))
sns.countplot(x='price_category', data=data, hue='price_category', palette="Set2")
plt.title("Distribution of Houses by Price Category")
plt.ylabel("Number of Houses")
plt.xlabel("Category")
plt.show()

# %%
# Number of listings vs Median Price (Top 10 States)
state_counts = data['state'].value_counts().head(10)
state_prices = data.groupby('state')['price'].median().loc[state_counts.index] 

plt.figure(figsize=(12,6))
plt.plot(state_counts.index, state_counts.values, marker='o', label='Number of Listings', color='brown')
plt.plot(state_prices.index, state_prices.values, marker='o', label='Median Price', color='teal')
plt.title("Number of Listings vs Median Price (Top 10 States)")
plt.xlabel("State")
plt.ylabel("Value")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# <div style="background-color: #00e7c8ff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #fff;" align="center"><strong> Final Insights</strong></h1>
# </div>

# %% [markdown]
# 1. Most property listings are concentrated in a few states like California , Florida , Texas , this indicates hot markets where real estate activity is high.
#
# 2. Categorization shows majority of listings fall in the mid-range segment, while luxury homes are concentrated in select states.
#
# 3. Price per square foot reveals where housing is truly expensive, regardless of size , some states show smaller but costlier houses, while others have larger affordable houses.
#
# 4. States like California , Florida , Texas , has more % of share as there are more listings.
#
# 5. Some states (e.g., California, New York) have significantly higher median prices compared to midwestern or southern states , this highlights regional affordability gaps.

# %% [markdown]
# <div style="background-color: #e7092eff; padding: 25px; border-radius: 10px;font-size:20px;font-weight:10px">
#   <h1 style="color: #242222ff;" align="center"><strong> Key Recommendations</strong></h1>
# </div>

# %% [markdown]
# 1. Focus on High-Activity States (California, Florida, Texas) : Since these states show the highest concentration of listings, investors and realtors should prioritize marketing and       expansion strategies here to maximize visibility and potential sales.
#
# 2. Diversify into Mid-Range Segments : As the majority of listings fall within the mid-range segment, targeting this group with affordable financing options, first-time buyer programs, and attractive mortgage rates can yield significant returns.
#
# 3. Capitalize on Luxury Niches in Select States : Luxury properties are concentrated in fewer states. Realtors should develop tailored marketing strategies highlighting exclusivity, lifestyle, and amenities to attract high-net-worth clients.
#
# 4. Price per Square Foot Analysis for Value Deals : Investors should consider states with larger, more affordable homes (low $/sqft) for rental or resale opportunities, while being cautious in states where smaller homes come at a high premium.
#
# 5. Regional Affordability Strategies : In high-cost states (California, New York), highlight rental investment potential due to demand , In more affordable regions (Midwest, South), focus on attracting relocators, retirees, and remote workers seeking cost-effective housing options.
